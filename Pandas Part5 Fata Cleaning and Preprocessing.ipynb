# %%
import pandas as pd
df = pd.read_csv("data_cleaning_sample.csv")

# %%
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df.isnull()  # in output table where there is True at those p[laces in data set we can understand that no value or object is present
# Out:
#     Name    Age   City  Gender  Email  Join Date
# 0  False  False  False   False  False      False
# 1  False   True  False   False  False      False
# 2  False  False  False   False  False      False
# 3  False   True  False   False  False      False
# 4  False  False  False   False  False      False
# 5   True  False  False   False  False       True
# 6  False  False  False   False  False      False
# 7  False  False  False   False  False      False
# 8  False   True  False   False  False      False

# %%
df.isnull().sum()   # Tells number of missing values present in each column
# Out:
# Name         1
# Age          3
# City         0
# Gender       0
# Email        0
# Join Date    1
# dtype: int64

# %%
df.dropna()   # it drops all the rows which have something missing and only gives rows which have all the values present
# Out:
#     Name   Age         City Gender              Email   Join Date
# 0  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 2    Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 4  David  22.0       Mumbai      M  david@example.com  12-11-2019
# 6  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7  Alice  25.0     New York      F  alice@example.com  01-05-2021

# %%
df.dropna(axis=1)  # here dropped a column and this is mainly used in machine learning where there are around 50 types and you dont want those many types to be used
# Out:
#           City Gender              Email
# 0     New York      F  alice@example.com
# 1        Delhi      M    charlie@example
# 2  Los Angeles      M    bob@example.com
# 3        Delhi      M    charlie@example
# 4       Mumbai      M  david@example.com
# 5        Delhi      F     eve@domain.com
# 6     New York      F  alice@example.com
# 7     New York      F  alice@example.com
# 8        Delhi      M    charlie@example

# %% [markdown]
# ## Difference between
# ### df.drop(to_drop, axis = 1)
# ### df.drop(to_drop, inplace = True,axis = 1)
# ## is that in inplace one it do changes in original df but without inplace it returns new dataframe so if we want to continue in doing it we can store it in new dataframe like df2

# %%
to_drop =['Email','Age']
df.drop(to_drop, axis = 1)
## df.drop(columns=to_drop, inplace=True) instead of axis = 1 we can directly mention columns and remove it
# Out:
#       Name         City Gender   Join Date
# 0    Alice     New York      F  01-05-2021
# 1  Charlie        Delhi      M  20-07-2021
# 2      Bob  Los Angeles      M  15-06-2020
# 3  Charlie        Delhi      M  20-07-2021
# 4    David       Mumbai      M  12-11-2019
# 5      NaN        Delhi      F         NaN
# 6    Alice     New York      F  01-05-2021
# 7    Alice     New York      F  01-05-2021
# 8  Charlie        Delhi      M  20-07-2021

# %%
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df.fillna(0)  # In places where Nan is present we change it to 0 it is done in a copy not in actual df changes
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   0.0        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   0.0        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5        0  28.0        Delhi      F     eve@domain.com           0
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   0.0        Delhi      M    charlie@example  20-07-2021

# %%
df["Age"].fillna(df["Age"].mean())   # What it does is that in places of Nan in age column it replaces it with mean
# Out:
# 0    25.000000
# 1    25.833333
# 2    30.000000
# 3    25.833333
# 4    22.000000
# 5    28.000000
# 6    25.000000
# 7    25.000000
# 8    25.833333
# Name: Age, dtype: float64

# %%
df.fillna(method = "ffill") # Forward Fill means if 3rd is Nan then it will take same value of 2nd 
# or use df.ffill()
# Out:
# C:\Users\Nilesh\AppData\Local\Temp\ipykernel_63040\3136771938.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = "ffill") # Forward Fill means if 3rd is Nan then it will take same value of 2nd
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie  25.0        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie  30.0        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5    David  28.0        Delhi      F     eve@domain.com  12-11-2019
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# ...

# %%
df.bfill() # df.fillna(method="bfill")
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie  30.0        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie  22.0        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5    Alice  28.0        Delhi      F     eve@domain.com  01-05-2021
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
index = ['A','B','C','D','E','F','G','H','I']
df1 = df.copy()          # assign dataframe here if we dont use copy() it do changes to original one
df1.index = index # set new index
df1
# Out:
#       Name   Age         City Gender              Email   Join Date
# A    Alice  25.0     New York      F  alice@example.com  01-05-2021
# B  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# C      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# D  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# E    David  22.0       Mumbai      M  david@example.com  12-11-2019
# F      NaN  28.0        Delhi      F     eve@domain.com         NaN
# G    Alice  25.0     New York      F  alice@example.com  01-05-2021
# H    Alice  25.0     New York      F  alice@example.com  01-05-2021
# I  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7     True
# 8     True
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN

# %%
df.duplicated(subset=["Name","Age"])
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7     True
# 8     True
# dtype: bool

# %%
df["Name"].str.lower()
# Out:
# 0      alice
# 1    charlie
# 2        bob
# 3    charlie
# 4      david
# 5        NaN
# 6      alice
# 7      alice
# 8    charlie
# Name: Name, dtype: object

# %%
df["City"].str.contains("delhi", case=False)
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# 7    False
# 8     True
# Name: City, dtype: bool

# %%
type(df["City"].str.contains("delhi", case=False))
# Out:
# pandas.core.series.Series

# %%
df["Email"].str.split("@")
# Out:
# 0    [alice, example.com]
# 1      [charlie, example]
# 2      [bob, example.com]
# 3      [charlie, example]
# 4    [david, example.com]
# 5       [eve, domain.com]
# 6    [alice, example.com]
# 7    [alice, example.com]
# 8      [charlie, example]
# Name: Email, dtype: object

# %%
df["Email"].str.split("@")[0]
# Out:
# ['alice', 'example.com']

# %%
type(df["Email"].str.split("@")[0])
# Out:
# list

# %%
df2 = df.dropna().copy()

# %%
df2["Age"] = df2["Age"].astype(int)

# %%
df2
# Out:
#     Name  Age         City Gender              Email   Join Date
# 0  Alice   25     New York      F  alice@example.com  01-05-2021
# 2    Bob   30  Los Angeles      M    bob@example.com  15-06-2020
# 4  David   22       Mumbai      M  david@example.com  12-11-2019
# 6  Alice   25     New York      F  alice@example.com  01-05-2021
# 7  Alice   25     New York      F  alice@example.com  01-05-2021

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       5 non-null      object
#  1   Age        5 non-null      int64
#  2   City       5 non-null      object
#  3   Gender     5 non-null      object
#  4   Email      5 non-null      object
#  5   Join Date  5 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 280.0+ bytes

# %%
df2.head()
# Out:
#     Name  Age         City Gender              Email   Join Date
# 0  Alice   25     New York      F  alice@example.com  01-05-2021
# 2    Bob   30  Los Angeles      M    bob@example.com  15-06-2020
# 4  David   22       Mumbai      M  david@example.com  12-11-2019
# 6  Alice   25     New York      F  alice@example.com  01-05-2021
# 7  Alice   25     New York      F  alice@example.com  01-05-2021

# %%
df2.head(1)
# Out:
#     Name  Age      City Gender              Email   Join Date
# 0  Alice   25  New York      F  alice@example.com  01-05-2021

# %%
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df2
# Out:
#     Name  Age         City Gender              Email   Join Date
# 0  Alice   25     New York      F  alice@example.com  01-05-2021
# 2    Bob   30  Los Angeles      M    bob@example.com  15-06-2020
# 4  David   22       Mumbai      M  david@example.com  12-11-2019
# 6  Alice   25     New York      F  alice@example.com  01-05-2021
# 7  Alice   25     New York      F  alice@example.com  01-05-2021

# %%
df2["Age Group"] = df2["Age"].apply(lambda x: "Adult" if x>=18 else "Minor")

# %%
df2
# Out:
#     Name  Age         City Gender              Email   Join Date Age Group
# 0  Alice   25     New York      F  alice@example.com  01-05-2021     Adult
# 2    Bob   30  Los Angeles      M    bob@example.com  15-06-2020     Adult
# 4  David   22       Mumbai      M  david@example.com  12-11-2019     Adult
# 6  Alice   25     New York      F  alice@example.com  01-05-2021     Adult
# 7  Alice   25     New York      F  alice@example.com  01-05-2021     Adult

# %%
df2["Age Group"] = df2["Age"].apply(lambda x: "Adult" if x>=25 else "Minor")

# %%
df2
# Out:
#     Name  Age         City Gender              Email   Join Date Age Group
# 0  Alice   25     New York      F  alice@example.com  01-05-2021     Adult
# 2    Bob   30  Los Angeles      M    bob@example.com  15-06-2020     Adult
# 4  David   22       Mumbai      M  david@example.com  12-11-2019     Minor
# 6  Alice   25     New York      F  alice@example.com  01-05-2021     Adult
# 7  Alice   25     New York      F  alice@example.com  01-05-2021     Adult

# %%
def isminor(x):
    return "Adult" if x>=30 else "Minor"
df2["Age Group"] = df2["Age"].apply(isminor)

# %%
df2
# Out:
#     Name  Age         City Gender              Email   Join Date Age Group
# 0  Alice   25     New York      F  alice@example.com  01-05-2021     Minor
# 2    Bob   30  Los Angeles      M    bob@example.com  15-06-2020     Adult
# 4  David   22       Mumbai      M  david@example.com  12-11-2019     Minor
# 6  Alice   25     New York      F  alice@example.com  01-05-2021     Minor
# 7  Alice   25     New York      F  alice@example.com  01-05-2021     Minor

# %%
gender_map = {"M":"Male","F":"Female","O":"Other"}
df2["Gender"] = df2["Gender"].map(gender_map)

# %%
df2
# Out:
#     Name  Age         City Gender              Email   Join Date Age Group
# 0  Alice   25     New York    NaN  alice@example.com  01-05-2021     Minor
# 2    Bob   30  Los Angeles    NaN    bob@example.com  15-06-2020     Adult
# 4  David   22       Mumbai    NaN  david@example.com  12-11-2019     Minor
# 6  Alice   25     New York    NaN  alice@example.com  01-05-2021     Minor
# 7  Alice   25     New York    NaN  alice@example.com  01-05-2021     Minor

# %%
df2["City"].replace({"Delhi": "New Delhi","Mumbai": "New Mumbai"})
df2
# Out:
#     Name  Age         City Gender              Email   Join Date Age Group
# 0  Alice   25     New York    NaN  alice@example.com  01-05-2021     Minor
# 2    Bob   30  Los Angeles    NaN    bob@example.com  15-06-2020     Adult
# 4  David   22       Mumbai    NaN  david@example.com  12-11-2019     Minor
# 6  Alice   25     New York    NaN  alice@example.com  01-05-2021     Minor
# 7  Alice   25     New York    NaN  alice@example.com  01-05-2021     Minor
